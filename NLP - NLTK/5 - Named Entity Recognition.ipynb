# %% [markdown]
# # Named Entity Recognition (NER)
#
#
# ---
#
#
#
# Bir cümle içerisindeki kişi isimleri, organizasyon isimleri lokasyon ve tarih bilgileri bulmayı amaçlar.

# %%
import nltk
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
text = "Steve Jobs was an American entrepreneur and business magnate. He was the chairman, chief executive officer (CEO), and a co-founder of Apple Inc., chairman and majority shareholder of Pixar, a member of The Walt Disney Company's board of directors following its acquisition of Pixar, and the founder, chairman, and CEO of NeXT. Jobs is widely recognized as a pioneer of the microcomputer revolution of the 1970s and 1980s, along with Apple co-founder Steve Wozniak.'"

# %%
nltk.download("punkt")
tokenized = nltk.word_tokenize(text)

# %%
nltk.download('averaged_perceptron_tagger')
tagged = nltk.pos_tag(tokenized)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
ner = nltk.ne_chunk(tagged)

# %%
# !pip install svgling
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting svgling
#   Downloading svgling-0.3.1-py3-none-any.whl (21 kB)
# Collecting svgwrite
#   Downloading svgwrite-1.4.3-py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 4.5 MB/s eta 0:00:00
# Installing collected packages: svgwrite, svgling
# Successfully installed svgling-0.3.1 svgwrite-1.4.3

# %%
ner
# Out:
# Tree('S', [Tree('PERSON', [('Steve', 'NNP')]), Tree('PERSON', [('Jobs', 'NNP')]), ('was', 'VBD'), ('an', 'DT'), Tree('GPE', [('American', 'JJ')]), ('entrepreneur', 'NN'), ('and', 'CC'), ('business', 'NN'), ('magnate', 'NN'), ('.', '.'), ('He', 'PRP'), ('was', 'VBD'), ('the', 'DT'), ('chairman', 'NN'), (',', ','), ('chief', 'JJ'), ('executive', 'NN'), ('officer', 'NN'), ('(', '('), Tree('ORGANIZATION', [('CEO', 'NNP')]), (')', ')'), (',', ','), ('and', 'CC'), ('a', 'DT'), ('co-founder', 'NN'), ('of', 'IN'), Tree('ORGANIZATION', [('Apple', 'NNP'), ('Inc.', 'NNP')]), (',', ','), ('chairman', 'NN'), ('and', 'CC'), ('majority', 'NN'), ('shareholder', 'NN'), ('of', 'IN'), Tree('GPE', [('Pixar', 'NNP')]), (',', ','), ('a', 'DT'), ('member', 'NN'), ('of', 'IN'), ('The', 'DT'), Tree('ORGANIZATION', [('Walt', 'NNP'), ('Disney', 'NNP'), ('Company', 'NNP')]), ("'s", 'POS'), ('board', 'NN'), ('of', 'IN'), ('directors', 'NNS'), ('following', 'VBG'), ('its', 'PRP$'), ('acquisition', 'NN'), ('of', 'IN'), Tree('GPE', [('Pixar', 'NNP')]), (',', ','), ('and', 'CC'), ('the', 'DT'), ('founder', 'NN'), (',', ','), ('chairman', 'NN'), (',', ','), ('and', 'CC'), Tree('ORGANIZATION', [('CEO', 'NNP')]), ('of', 'IN'), Tree('ORGANIZATION', [('NeXT', 'NNP')]), ('.', '.'), Tree('PERSON', [('Jobs', 'NNP')]), ('is', 'VBZ'), ('widely', 'RB'), ('recognized', 'VBN'), ('as', 'IN'), ('a', 'DT'), ('pioneer', 'NN'), ('of', 'IN'), ('the', 'DT'), ('microcomputer', 'NN'), ('revolution', 'NN'), ('of', 'IN'), ('the', 'DT'), ('1970s', 'CD'), ('and', 'CC'), ('1980s', 'CD'), (',', ','), ('along', 'IN'), ('with', 'IN'), Tree('PERSON', [('Apple', 'NNP')]), ('co-founder', 'NN'), Tree('PERSON', [('Steve', 'NNP'), ('Wozniak', 'NNP')]), ('.', '.'), ("'", "''")])

# %%
"""
NE Türü         	Örnek
ORGANIZATION    	Georgia-Pacific Corp., WHO
PERSON          	Eddy Bonte, President Obama
LOCATION        	Murray River, Mount Everest
DATE            	June, 2008-06-29
TIME            	two fifty a m, 1:30 p.m.
MONEY           	175 million Canadian Dollars, GBP 10.40
PERCENT         	twenty pct, 18.75 %
FACILITY        	Washington Monument, Stonehenge
GPE             	South East Asia, Midlothian
"""
